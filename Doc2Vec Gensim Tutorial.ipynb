# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
import logging
import os
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s",\
                   level=logging.INFO)

# %% [markdown]
# # Small In Memory Example
# ***
# We will manually define some sentences, and use the `TaggedDocument` data structure to have a list of `TaggedDocument` objects. Each sentence is a document in this case, and its tag is its index in the list.

# %%
documents = ["I love machine learning. Its awesome.",
       "I love coding in python",
       "I love building chatbots",
       "they chat amagingly well"]
# a list of TaggedDocument objects (sentences)
tagged_data = [TaggedDocument(words=word_tokenize(sentence.lower()), tags=[str(i)]) for i, sentence in enumerate(documents)]

# %% [markdown]
# Now we have a list of four sentences of training data.

# %%
tagged_data
# Out:
# [TaggedDocument(words=['i', 'love', 'machine', 'learning', '.', 'its', 'awesome', '.'], tags=['0']),
#  TaggedDocument(words=['i', 'love', 'coding', 'in', 'python'], tags=['1']),
#  TaggedDocument(words=['i', 'love', 'building', 'chatbots'], tags=['2']),
#  TaggedDocument(words=['they', 'chat', 'amagingly', 'well'], tags=['3'])]

# %% [markdown]
# `dm` defines the training algorithm. `dm=1` means distributed memory and `dm=0` means distributed bag of words. The distributed memory model preserves word order in a document, whereas bag of words does not

# %%
max_epochs = 100
vec_size = 20
alpha = 0.025

model = Doc2Vec(vector_size=vec_size,
               alpha=alpha,
               min_alpha=0.00025,
               min_count=1,
               dm=1)

model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    logging.info("Epoch: {}".format(epoch))
    
    model.train(tagged_data, 
                total_examples=model.corpus_count, 
                epochs=model.iter)
    model.alpha -= 0.0002
    model.min_alpha = model.alpha
# Out:
# /home/joseph/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   from ipykernel import kernelapp as app
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %% [markdown]
# Now we can save the model:

# %%
model.save("data/doc2vec.model")
# Out:
# /home/joseph/miniconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# Now we can load and play with it:

# %%
model = Doc2Vec.load("data/doc2vec.model")

test_sentence = "I love chatbots"
test_data = word_tokenize(test_sentence.lower())
vec = model.infer_vector(test_data)
print("Vector inferred from sentence:\n{}->\n{}".format(test_sentence,vec))
# Out:
# Vector inferred from sentence:
# I love chatbots->
# [ 0.02188428 -0.00057101 -0.01809273  0.04565398  0.0376552  -0.01517666
#  -0.03909002 -0.0026375  -0.0059761   0.01059998 -0.01804322 -0.01692442
#   0.05742316  0.01855473 -0.00890092 -0.07206926 -0.04325558  0.04320221
#  -0.03700936 -0.00157744]

# %% [markdown]
# Find most similar doc using tags:

# %%
similar_doc = model.docvecs.most_similar("1",topn=1)
print(similar_doc)
# Out:
# [('0', 0.9935578107833862)]

# %% [markdown]
# Print the vector for document at index 1 in training data:

# %%
print(model.docvecs['1'])
# Out:
# [ 0.19112408 -0.05284713 -0.00806603  0.5364271   0.3120089  -0.08068791
#  -0.15005417 -0.12068697 -0.15206137  0.2529414  -0.12449547 -0.24706307
#   0.32597885  0.13146715  0.07459036 -0.37053815 -0.49766836  0.25876194
#  -0.32637128 -0.13382992]

# %% [markdown]
# # Example Loading Multiple Data Files in a Directory
# ***
# Now we will pass a directory path containing text files.
#
# You could do it like this:
#
# ```python
# data = []
# for file in os.listdir(DIR_PATH):
#     with open(os.path.join(DIR_PATH,file),'r') as file:
#         text = file.read()
#     cleaned_tokens = preprocess(text)
#     data.append(cleaned_tokens)
# ```
#
# But this is the same thing as just reading all of the text in your entire corpus into memory all at once.
#
# Instead, you should encapsulate a generator inside your class that you pass to your Doc2Vec Model.
#
# The input to a Doc2Vec Model is an iterator of `LabeledSentence` objects. However, the `LabeledSentence` class is now deprecated. Use `TaggedDocument` instead ([documentation](https://radimrehurek.com/gensim/models/doc2vec.html#gensim.models.doc2vec.TaggedDocument)).
#
# A `TaggedDocument` is a single document, made up of words (a list of unicode string token) and tags (list of tokens). Best practice is to make the tags list a list of unique integer ids.
#
# So we need to create a lazy iterator to consume the documents in a certain directory.
#
# The input to Doc2Vec will be our iterator of `TaggedDocument` objects.

# %%
class Document_Directory_Iterator(object):
    """
    Given a directory, lazily loop over files and read each one as a document 
    """
    def __init__(self, DIR_NAME, EXT="txt", preprocess=None):
        """
        Args:
            DIR_NAME (str): name of directory
            EXT (str): extension of document files
            preprocess (function): preprocessing to perform
        """
        self.DIRS = [DIR_NAME]
        self.EXT = EXT
        self.doc_list = [os.path.join(DIR_NAME,file) for file in os.listdir(DIR_NAME) \
                         if file.endswith(self.EXT)]
        self.preprocess = preprocess
        # keep track of how many documents have been read in
        self.docs_read = 0
    def add_dir(self, DIR_NAME):
        """
        Add a directory name to list of directories. Add all of the new file paths to our 
        documents list in that case
        
        Args:
            DIR_NAME (str): name of directory to add to directories
        """
        self.DIRS.append(DIR_NAME)
        self.doc_list = self.doc_list + [os.path.join(DIR_NAME,file) for file in os.listdir(DIR_NAME) \
                                         if file.endswith(self.EXT)]
    def get_dirs(self):
        return self.DIRS
    def __iter__(self):
        """
        Loop over files in self.doc_list lazily, preprocess, tokenize and yield TaggedDocuments
        """
        for file_path in self.doc_list:
            self.docs_read += 1
            with open(file_path,"r") as file:
                document_text = file.read()
            # preprocess and tokenize the text here
            if self.preprocess is not None:
                document_text = self.preprocess(document_text)
                yield TaggedDocument(words=word_tokenize(document_text), 
                                 tags=[str(self.docs_read)])
            else:
                yield TaggedDocument(words=word_tokenize(document_text.lower()), 
                                 tags=[str(self.docs_read)])

# %% [markdown]
# And we can test our trained model, given another file:

# %%
print(model.most_similar("path-to-test-doc"))

# %% [markdown]
# # IMDB Sentiment Dataset Example
# ***
# We will recreate the results of [Le and Mikolov 2014](https://arxiv.org/pdf/1405.4053.pdf).
#
# ## Load the Data
# ***

# %%
import re
def normalize_text(text):
    norm_text = text.lower()
    # replace line breaks with spaces
    norm_text = norm_text.replace("<br />", " ")
    # add spaces to both sides of every punctuation
    norm_text = re.sub(r"([\.\",\(\)!\?;:])"," \\1 ", norm_text)
    return norm_text

# %% [markdown]
# ## Train Model
# ***
# We load all of the directories into our lazy iterator, and then run the `build_vocab` over our iterator, as well as our `train` over the iterator.

# %%
# %%time 
import multiprocessing
cores = multiprocessing.cpu_count()
base_dir = "data/imdb_movie_reviews/"
model = Doc2Vec(vector_size=100, window=10, min_count=5, workers=cores, alpha=0.025, min_alpha=0.025)

document_iterator = Document_Directory_Iterator(os.path.join(base_dir, "train","unsup"),EXT="txt",
                                               preprocess=normalize_text)

for data_set in ["train","test"]:
    for data_label in ["neg","pos"]:
        document_iterator.add_dir(os.path.join(base_dir, data_set, data_label))

print("Directories loaded: {}".format(document_iterator.get_dirs()))
# %time model.build_vocab(document_iterator)
# Out:
# 2019-08-20 16:34:19,032 : INFO : collecting all words and their counts
# 2019-08-20 16:34:19,034 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# Directories loaded: ['data/imdb_movie_reviews/train/unsup', 'data/imdb_movie_reviews/train/neg', 'data/imdb_movie_reviews/train/pos', 'data/imdb_movie_reviews/test/neg', 'data/imdb_movie_reviews/test/pos']
# 2019-08-20 16:34:42,016 : INFO : PROGRESS: at example #10000, processed 2680835 words (116651/s), 64350 word types, 10000 tags
# 2019-08-20 16:35:04,993 : INFO : PROGRESS: at example #20000, processed 5381296 words (117535/s), 91560 word types, 20000 tags
# 2019-08-20 16:35:27,747 : INFO : PROGRESS: at example #30000, processed 8054600 words (117486/s), 112361 word types, 30000 tags
# 2019-08-20 16:35:51,093 : INFO : PROGRESS: at example #40000, processed 10793941 words (117341/s), 130895 word types, 40000 tags
# 2019-08-20 16:36:14,479 : INFO : PROGRESS: at example #50000, processed 13511422 words (116202/s), 147337 word types, 50000 tags
# 2019-08-20 16:36:37,657 : INFO : PROGRESS: at example #60000, processed 16176594 words (114991/s), 162993 word types, 60000 tags
# 2019-08-20 16:37:00,435 : INFO : PROGRESS: at example #70000, processed 18889135 words (119088/s), 178081 word types, 70000 tags
# 2019-08-20 16:37:23,198 : INFO : PROGRESS: at example #80000, processed 21577961 words (118124/s), 191809 word types, 80000 tags
# 2019-08-20 16:37:45,838 : INFO : PROGRESS: at example #90000, processed 24211189 words (116311/s), 204779 word types, 90000 tags
# 2019-08-20 16:38:07,770 : INFO : collected 217270 word types and 100000 unique tags from a corpus of 100000 examples and 26838128 words
# 2019-08-20 16:38:07,771 : INFO : Loading a fresh vocabulary
# 2019-08-20 16:38:08,006 : INFO : min_count=5 retains 59273 unique words (27% of original 217270, drops 157997)
# 2019-08-20 16:38:08,007 : INFO : min_count=5 leaves 26608345 word corpus (99% of original 26838128, drops 229783)
# 2019-08-20 16:38:08,190 : INFO : deleting the raw counts dictionary of 217270 items
# 2019-08-20 16:38:08,196 : INFO : sample=0.001 downsamples 49 most-common words
# 2019-08-20 16:38:08,197 : INFO : downsampling leaves estimated 18803159 word corpus (70.7% of prior 26608345)
# 2019-08-20 16:38:08,372 : INFO : estimated required memory for 59273 words and 100 dimensions: 137054900 bytes
# 2019-08-20 16:38:08,373 : INFO : resetting layer weights
# CPU times: user 3min 49s, sys: 1.18 s, total: 3min 50s
# Wall time: 3min 51s
# CPU times: user 3min 49s, sys: 1.25 s, total: 3min 51s
# Wall time: 3min 51s

# %%
# %time model.train(document_iterator, epochs=3,total_examples=model.corpus_count)
# Out:
# 2019-08-20 16:38:10,079 : INFO : training model with 8 workers on 59273 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2019-08-20 16:38:11,698 : INFO : EPOCH 1 - PROGRESS: at 0.04% examples, 4242 words/s, in_qsize 10, out_qsize 0
# 2019-08-20 16:38:12,837 : INFO : EPOCH 1 - PROGRESS: at 0.31% examples, 19802 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:13,853 : INFO : EPOCH 1 - PROGRESS: at 0.72% examples, 34472 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:14,860 : INFO : EPOCH 1 - PROGRESS: at 1.13% examples, 43005 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:15,888 : INFO : EPOCH 1 - PROGRESS: at 1.54% examples, 48460 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:16,895 : INFO : EPOCH 1 - PROGRESS: at 1.94% examples, 52344 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:17,916 : INFO : EPOCH 1 - PROGRESS: at 2.34% examples, 55212 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:18,994 : INFO : EPOCH 1 - PROGRESS: at 2.80% examples, 57824 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:20,100 : INFO : EPOCH 1 - PROGRESS: at 3.24% examples, 59720 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:38:21,179 : INFO : EPOCH 1 - PROGRESS: at 3.68% examples, 61395 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:22,258 : INFO : EPOCH 1 - PROGRESS: at 4.11% examples, 62685 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:23,264 : INFO : EPOCH 1 - PROGRESS: at 4.52% examples, 63671 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:24,323 : INFO : EPOCH 1 - PROGRESS: at 4.96% examples, 64708 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:25,367 : INFO : EPOCH 1 - PROGRESS: at 5.36% examples, 65201 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:26,430 : INFO : EPOCH 1 - PROGRESS: at 5.80% examples, 66034 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:27,431 : INFO : EPOCH 1 - PROGRESS: at 6.19% examples, 66608 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:28,437 : INFO : EPOCH 1 - PROGRESS: at 6.56% examples, 67087 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:29,582 : INFO : EPOCH 1 - PROGRESS: at 7.04% examples, 67717 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:30,593 : INFO : EPOCH 1 - PROGRESS: at 7.44% examples, 68056 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:31,671 : INFO : EPOCH 1 - PROGRESS: at 7.90% examples, 68462 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:32,696 : INFO : EPOCH 1 - PROGRESS: at 8.29% examples, 68723 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:33,712 : INFO : EPOCH 1 - PROGRESS: at 8.70% examples, 69257 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:34,757 : INFO : EPOCH 1 - PROGRESS: at 9.13% examples, 69389 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:35,781 : INFO : EPOCH 1 - PROGRESS: at 9.53% examples, 69556 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:36,848 : INFO : EPOCH 1 - PROGRESS: at 9.95% examples, 69885 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:37,857 : INFO : EPOCH 1 - PROGRESS: at 10.34% examples, 70060 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:38,860 : INFO : EPOCH 1 - PROGRESS: at 10.73% examples, 70194 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:39,906 : INFO : EPOCH 1 - PROGRESS: at 11.12% examples, 70244 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:41,022 : INFO : EPOCH 1 - PROGRESS: at 11.59% examples, 70372 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:42,109 : INFO : EPOCH 1 - PROGRESS: at 12.06% examples, 70554 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:43,133 : INFO : EPOCH 1 - PROGRESS: at 12.46% examples, 70672 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:44,142 : INFO : EPOCH 1 - PROGRESS: at 12.83% examples, 70793 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:45,144 : INFO : EPOCH 1 - PROGRESS: at 13.22% examples, 70911 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:46,169 : INFO : EPOCH 1 - PROGRESS: at 13.63% examples, 70994 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:47,240 : INFO : EPOCH 1 - PROGRESS: at 14.07% examples, 71187 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:38:48,255 : INFO : EPOCH 1 - PROGRESS: at 14.49% examples, 71279 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:49,347 : INFO : EPOCH 1 - PROGRESS: at 14.92% examples, 71402 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:50,420 : INFO : EPOCH 1 - PROGRESS: at 15.35% examples, 71519 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:51,451 : INFO : EPOCH 1 - PROGRESS: at 15.74% examples, 71556 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:38:52,451 : INFO : EPOCH 1 - PROGRESS: at 16.14% examples, 71652 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:38:53,468 : INFO : EPOCH 1 - PROGRESS: at 16.54% examples, 71712 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:54,528 : INFO : EPOCH 1 - PROGRESS: at 16.98% examples, 71857 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:55,610 : INFO : EPOCH 1 - PROGRESS: at 17.43% examples, 71963 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:56,613 : INFO : EPOCH 1 - PROGRESS: at 17.81% examples, 72010 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:57,626 : INFO : EPOCH 1 - PROGRESS: at 18.18% examples, 72057 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:58,714 : INFO : EPOCH 1 - PROGRESS: at 18.60% examples, 72138 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:38:59,755 : INFO : EPOCH 1 - PROGRESS: at 19.06% examples, 72444 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:39:00,772 : INFO : EPOCH 1 - PROGRESS: at 19.39% examples, 72209 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:01,785 : INFO : EPOCH 1 - PROGRESS: at 19.79% examples, 72246 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:02,845 : INFO : EPOCH 1 - PROGRESS: at 20.20% examples, 72232 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:03,852 : INFO : EPOCH 1 - PROGRESS: at 20.62% examples, 72288 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:04,954 : INFO : EPOCH 1 - PROGRESS: at 21.05% examples, 72334 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:05,962 : INFO : EPOCH 1 - PROGRESS: at 21.43% examples, 72380 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:07,072 : INFO : EPOCH 1 - PROGRESS: at 21.89% examples, 72407 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:08,176 : INFO : EPOCH 1 - PROGRESS: at 22.32% examples, 72454 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:09,221 : INFO : EPOCH 1 - PROGRESS: at 22.70% examples, 72434 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:10,228 : INFO : EPOCH 1 - PROGRESS: at 23.15% examples, 72485 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:11,311 : INFO : EPOCH 1 - PROGRESS: at 23.57% examples, 72552 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:12,354 : INFO : EPOCH 1 - PROGRESS: at 23.96% examples, 72548 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:13,418 : INFO : EPOCH 1 - PROGRESS: at 24.39% examples, 72616 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:14,499 : INFO : EPOCH 1 - PROGRESS: at 24.83% examples, 72686 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:15,607 : INFO : EPOCH 1 - PROGRESS: at 25.28% examples, 72720 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:16,653 : INFO : EPOCH 1 - PROGRESS: at 25.69% examples, 72721 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:39:17,737 : INFO : EPOCH 1 - PROGRESS: at 26.16% examples, 72772 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:18,753 : INFO : EPOCH 1 - PROGRESS: at 26.55% examples, 72789 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:19,783 : INFO : EPOCH 1 - PROGRESS: at 26.95% examples, 72803 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:20,861 : INFO : EPOCH 1 - PROGRESS: at 27.38% examples, 72863 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:21,957 : INFO : EPOCH 1 - PROGRESS: at 27.81% examples, 72899 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:23,117 : INFO : EPOCH 1 - PROGRESS: at 28.31% examples, 72958 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:24,229 : INFO : EPOCH 1 - PROGRESS: at 28.75% examples, 72985 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:25,295 : INFO : EPOCH 1 - PROGRESS: at 29.19% examples, 73042 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:26,311 : INFO : EPOCH 1 - PROGRESS: at 29.60% examples, 73057 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:27,329 : INFO : EPOCH 1 - PROGRESS: at 30.00% examples, 73072 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:28,347 : INFO : EPOCH 1 - PROGRESS: at 30.40% examples, 73089 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:29,358 : INFO : EPOCH 1 - PROGRESS: at 30.82% examples, 73112 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:30,361 : INFO : EPOCH 1 - PROGRESS: at 31.23% examples, 73152 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:31,433 : INFO : EPOCH 1 - PROGRESS: at 31.66% examples, 73196 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:32,524 : INFO : EPOCH 1 - PROGRESS: at 32.07% examples, 73224 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:33,637 : INFO : EPOCH 1 - PROGRESS: at 32.52% examples, 73244 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:34,747 : INFO : EPOCH 1 - PROGRESS: at 32.93% examples, 73252 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:35,905 : INFO : EPOCH 1 - PROGRESS: at 33.42% examples, 73294 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:37,062 : INFO : EPOCH 1 - PROGRESS: at 33.86% examples, 73350 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:38,075 : INFO : EPOCH 1 - PROGRESS: at 34.26% examples, 73368 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:39,083 : INFO : EPOCH 1 - PROGRESS: at 34.65% examples, 73386 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:40,149 : INFO : EPOCH 1 - PROGRESS: at 35.07% examples, 73437 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:41,249 : INFO : EPOCH 1 - PROGRESS: at 35.50% examples, 73460 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:42,261 : INFO : EPOCH 1 - PROGRESS: at 35.89% examples, 73471 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:43,400 : INFO : EPOCH 1 - PROGRESS: at 36.33% examples, 73532 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:44,404 : INFO : EPOCH 1 - PROGRESS: at 36.72% examples, 73558 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:45,469 : INFO : EPOCH 1 - PROGRESS: at 37.14% examples, 73599 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:46,552 : INFO : EPOCH 1 - PROGRESS: at 37.57% examples, 73631 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:47,605 : INFO : EPOCH 1 - PROGRESS: at 38.01% examples, 73679 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:48,617 : INFO : EPOCH 1 - PROGRESS: at 38.41% examples, 73688 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:49,786 : INFO : EPOCH 1 - PROGRESS: at 38.88% examples, 73718 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:50,798 : INFO : EPOCH 1 - PROGRESS: at 39.32% examples, 73791 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:51,850 : INFO : EPOCH 1 - PROGRESS: at 39.70% examples, 73763 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:52,870 : INFO : EPOCH 1 - PROGRESS: at 40.10% examples, 73760 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:53,949 : INFO : EPOCH 1 - PROGRESS: at 40.55% examples, 73785 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:55,043 : INFO : EPOCH 1 - PROGRESS: at 40.99% examples, 73811 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:56,066 : INFO : EPOCH 1 - PROGRESS: at 41.38% examples, 73808 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:57,072 : INFO : EPOCH 1 - PROGRESS: at 41.78% examples, 73818 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:39:58,094 : INFO : EPOCH 1 - PROGRESS: at 42.16% examples, 73819 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:39:59,186 : INFO : EPOCH 1 - PROGRESS: at 42.57% examples, 73830 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:00,221 : INFO : EPOCH 1 - PROGRESS: at 42.98% examples, 73830 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:01,233 : INFO : EPOCH 1 - PROGRESS: at 43.38% examples, 73841 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:02,304 : INFO : EPOCH 1 - PROGRESS: at 43.84% examples, 73880 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:03,316 : INFO : EPOCH 1 - PROGRESS: at 44.22% examples, 73875 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:04,325 : INFO : EPOCH 1 - PROGRESS: at 44.62% examples, 73881 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:40:05,330 : INFO : EPOCH 1 - PROGRESS: at 45.01% examples, 73895 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:06,339 : INFO : EPOCH 1 - PROGRESS: at 45.39% examples, 73901 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:07,370 : INFO : EPOCH 1 - PROGRESS: at 45.76% examples, 73897 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:08,372 : INFO : EPOCH 1 - PROGRESS: at 46.15% examples, 73907 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:09,396 : INFO : EPOCH 1 - PROGRESS: at 46.59% examples, 73965 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:40:10,412 : INFO : EPOCH 1 - PROGRESS: at 46.98% examples, 73914 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:11,435 : INFO : EPOCH 1 - PROGRESS: at 47.36% examples, 73911 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:12,505 : INFO : EPOCH 1 - PROGRESS: at 47.80% examples, 73937 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:13,555 : INFO : EPOCH 1 - PROGRESS: at 48.21% examples, 73918 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:14,585 : INFO : EPOCH 1 - PROGRESS: at 48.59% examples, 73913 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:15,674 : INFO : EPOCH 1 - PROGRESS: at 49.02% examples, 73920 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:16,764 : INFO : EPOCH 1 - PROGRESS: at 49.45% examples, 73934 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:17,836 : INFO : EPOCH 1 - PROGRESS: at 49.85% examples, 73902 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:18,968 : INFO : EPOCH 1 - PROGRESS: at 50.24% examples, 73838 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:20,011 : INFO : EPOCH 1 - PROGRESS: at 50.64% examples, 73829 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:21,038 : INFO : EPOCH 1 - PROGRESS: at 51.04% examples, 73828 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:22,067 : INFO : EPOCH 1 - PROGRESS: at 51.45% examples, 73826 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:23,103 : INFO : EPOCH 1 - PROGRESS: at 51.85% examples, 73821 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:40:24,107 : INFO : EPOCH 1 - PROGRESS: at 52.28% examples, 73831 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:25,118 : INFO : EPOCH 1 - PROGRESS: at 52.70% examples, 73838 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:26,165 : INFO : EPOCH 1 - PROGRESS: at 53.10% examples, 73825 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:27,213 : INFO : EPOCH 1 - PROGRESS: at 53.51% examples, 73817 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:28,243 : INFO : EPOCH 1 - PROGRESS: at 53.92% examples, 73820 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:29,286 : INFO : EPOCH 1 - PROGRESS: at 54.35% examples, 73814 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:30,379 : INFO : EPOCH 1 - PROGRESS: at 54.79% examples, 73824 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:31,410 : INFO : EPOCH 1 - PROGRESS: at 55.19% examples, 73816 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:32,540 : INFO : EPOCH 1 - PROGRESS: at 55.61% examples, 73805 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:33,542 : INFO : EPOCH 1 - PROGRESS: at 56.00% examples, 73770 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:34,690 : INFO : EPOCH 1 - PROGRESS: at 56.42% examples, 73750 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:35,693 : INFO : EPOCH 1 - PROGRESS: at 56.83% examples, 73766 words/s, in_qsize 15, out_qsize 1
# 2019-08-20 16:40:36,710 : INFO : EPOCH 1 - PROGRESS: at 57.22% examples, 73769 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:37,722 : INFO : EPOCH 1 - PROGRESS: at 57.62% examples, 73776 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:38,801 : INFO : EPOCH 1 - PROGRESS: at 58.05% examples, 73796 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:39,828 : INFO : EPOCH 1 - PROGRESS: at 58.43% examples, 73799 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:40,834 : INFO : EPOCH 1 - PROGRESS: at 58.84% examples, 73811 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:41,844 : INFO : EPOCH 1 - PROGRESS: at 59.24% examples, 73819 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:42,873 : INFO : EPOCH 1 - PROGRESS: at 59.66% examples, 73811 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:43,900 : INFO : EPOCH 1 - PROGRESS: at 60.07% examples, 73806 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:44,924 : INFO : EPOCH 1 - PROGRESS: at 60.45% examples, 73808 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:45,945 : INFO : EPOCH 1 - PROGRESS: at 60.85% examples, 73809 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:46,970 : INFO : EPOCH 1 - PROGRESS: at 61.26% examples, 73812 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:48,008 : INFO : EPOCH 1 - PROGRESS: at 61.66% examples, 73809 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:49,052 : INFO : EPOCH 1 - PROGRESS: at 62.14% examples, 73886 words/s, in_qsize 13, out_qsize 1
# 2019-08-20 16:40:50,074 : INFO : EPOCH 1 - PROGRESS: at 62.52% examples, 73847 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:51,133 : INFO : EPOCH 1 - PROGRESS: at 62.90% examples, 73831 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:52,185 : INFO : EPOCH 1 - PROGRESS: at 63.33% examples, 73859 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:53,255 : INFO : EPOCH 1 - PROGRESS: at 63.82% examples, 73917 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:40:54,342 : INFO : EPOCH 1 - PROGRESS: at 64.20% examples, 73880 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:55,378 : INFO : EPOCH 1 - PROGRESS: at 64.60% examples, 73875 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:56,433 : INFO : EPOCH 1 - PROGRESS: at 65.03% examples, 73901 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:40:57,451 : INFO : EPOCH 1 - PROGRESS: at 65.44% examples, 73906 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:58,494 : INFO : EPOCH 1 - PROGRESS: at 65.85% examples, 73932 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:40:59,526 : INFO : EPOCH 1 - PROGRESS: at 66.26% examples, 73927 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:00,603 : INFO : EPOCH 1 - PROGRESS: at 66.69% examples, 73943 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:41:01,603 : INFO : EPOCH 1 - PROGRESS: at 67.11% examples, 73954 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:02,674 : INFO : EPOCH 1 - PROGRESS: at 67.54% examples, 73968 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:03,734 : INFO : EPOCH 1 - PROGRESS: at 67.98% examples, 73991 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:41:04,784 : INFO : EPOCH 1 - PROGRESS: at 68.40% examples, 74020 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:05,862 : INFO : EPOCH 1 - PROGRESS: at 68.80% examples, 74030 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:06,958 : INFO : EPOCH 1 - PROGRESS: at 69.23% examples, 74035 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:08,094 : INFO : EPOCH 1 - PROGRESS: at 69.63% examples, 73980 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:09,164 : INFO : EPOCH 1 - PROGRESS: at 69.99% examples, 73926 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:10,254 : INFO : EPOCH 1 - PROGRESS: at 70.42% examples, 73933 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:11,347 : INFO : EPOCH 1 - PROGRESS: at 70.85% examples, 73943 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:12,454 : INFO : EPOCH 1 - PROGRESS: at 71.28% examples, 73942 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:13,524 : INFO : EPOCH 1 - PROGRESS: at 71.72% examples, 73958 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:14,590 : INFO : EPOCH 1 - PROGRESS: at 72.15% examples, 73977 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:15,674 : INFO : EPOCH 1 - PROGRESS: at 72.58% examples, 73989 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:16,809 : INFO : EPOCH 1 - PROGRESS: at 73.05% examples, 74012 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:17,847 : INFO : EPOCH 1 - PROGRESS: at 73.41% examples, 73999 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:41:18,865 : INFO : EPOCH 1 - PROGRESS: at 73.92% examples, 74108 words/s, in_qsize 13, out_qsize 0
# 2019-08-20 16:41:19,904 : INFO : EPOCH 1 - PROGRESS: at 74.25% examples, 74025 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:20,965 : INFO : EPOCH 1 - PROGRESS: at 74.64% examples, 74005 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:21,981 : INFO : EPOCH 1 - PROGRESS: at 75.08% examples, 74045 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:41:23,023 : INFO : EPOCH 1 - PROGRESS: at 75.43% examples, 74002 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:24,145 : INFO : EPOCH 1 - PROGRESS: at 75.87% examples, 73996 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:25,311 : INFO : EPOCH 1 - PROGRESS: at 76.31% examples, 73979 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:26,407 : INFO : EPOCH 1 - PROGRESS: at 76.75% examples, 73987 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:27,430 : INFO : EPOCH 1 - PROGRESS: at 77.17% examples, 73984 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:28,529 : INFO : EPOCH 1 - PROGRESS: at 77.58% examples, 73991 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:29,580 : INFO : EPOCH 1 - PROGRESS: at 78.01% examples, 73980 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:30,629 : INFO : EPOCH 1 - PROGRESS: at 78.39% examples, 73968 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:31,799 : INFO : EPOCH 1 - PROGRESS: at 78.84% examples, 73949 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:32,821 : INFO : EPOCH 1 - PROGRESS: at 79.27% examples, 73950 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:33,871 : INFO : EPOCH 1 - PROGRESS: at 79.70% examples, 73936 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:34,888 : INFO : EPOCH 1 - PROGRESS: at 80.09% examples, 73936 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:35,956 : INFO : EPOCH 1 - PROGRESS: at 80.51% examples, 73921 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:36,978 : INFO : EPOCH 1 - PROGRESS: at 80.94% examples, 73924 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:38,045 : INFO : EPOCH 1 - PROGRESS: at 81.36% examples, 73911 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:39,111 : INFO : EPOCH 1 - PROGRESS: at 81.74% examples, 73862 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:40,138 : INFO : EPOCH 1 - PROGRESS: at 82.12% examples, 73829 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:41,201 : INFO : EPOCH 1 - PROGRESS: at 82.51% examples, 73816 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:42,255 : INFO : EPOCH 1 - PROGRESS: at 82.92% examples, 73803 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:43,330 : INFO : EPOCH 1 - PROGRESS: at 83.34% examples, 73786 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:44,373 : INFO : EPOCH 1 - PROGRESS: at 83.75% examples, 73781 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:45,412 : INFO : EPOCH 1 - PROGRESS: at 84.18% examples, 73772 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:46,449 : INFO : EPOCH 1 - PROGRESS: at 84.61% examples, 73765 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:41:47,499 : INFO : EPOCH 1 - PROGRESS: at 84.99% examples, 73757 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:48,546 : INFO : EPOCH 1 - PROGRESS: at 85.38% examples, 73751 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:49,596 : INFO : EPOCH 1 - PROGRESS: at 85.81% examples, 73744 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:50,597 : INFO : EPOCH 1 - PROGRESS: at 86.22% examples, 73754 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:41:51,696 : INFO : EPOCH 1 - PROGRESS: at 86.59% examples, 73700 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:52,706 : INFO : EPOCH 1 - PROGRESS: at 87.00% examples, 73710 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:53,802 : INFO : EPOCH 1 - PROGRESS: at 87.44% examples, 73721 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:54,802 : INFO : EPOCH 1 - PROGRESS: at 87.83% examples, 73729 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:55,891 : INFO : EPOCH 1 - PROGRESS: at 88.28% examples, 73737 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:56,903 : INFO : EPOCH 1 - PROGRESS: at 88.66% examples, 73740 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:41:57,912 : INFO : EPOCH 1 - PROGRESS: at 89.07% examples, 73746 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:41:59,004 : INFO : EPOCH 1 - PROGRESS: at 89.53% examples, 73755 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:42:00,080 : INFO : EPOCH 1 - PROGRESS: at 89.97% examples, 73766 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:01,201 : INFO : EPOCH 1 - PROGRESS: at 90.46% examples, 73793 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:02,223 : INFO : EPOCH 1 - PROGRESS: at 90.86% examples, 73789 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:03,375 : INFO : EPOCH 1 - PROGRESS: at 91.33% examples, 73804 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:04,461 : INFO : EPOCH 1 - PROGRESS: at 91.79% examples, 73813 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:05,572 : INFO : EPOCH 1 - PROGRESS: at 92.24% examples, 73812 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:06,573 : INFO : EPOCH 1 - PROGRESS: at 92.66% examples, 73820 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:07,638 : INFO : EPOCH 1 - PROGRESS: at 93.11% examples, 73835 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:08,669 : INFO : EPOCH 1 - PROGRESS: at 93.52% examples, 73831 words/s, in_qsize 15, out_qsize 1
# 2019-08-20 16:42:09,883 : INFO : EPOCH 1 - PROGRESS: at 93.98% examples, 73827 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:11,033 : INFO : EPOCH 1 - PROGRESS: at 94.44% examples, 73819 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:12,050 : INFO : EPOCH 1 - PROGRESS: at 94.90% examples, 73848 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:42:13,103 : INFO : EPOCH 1 - PROGRESS: at 95.25% examples, 73781 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:14,182 : INFO : EPOCH 1 - PROGRESS: at 95.64% examples, 73767 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:15,219 : INFO : EPOCH 1 - PROGRESS: at 96.11% examples, 73790 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:16,237 : INFO : EPOCH 1 - PROGRESS: at 96.47% examples, 73764 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:17,305 : INFO : EPOCH 1 - PROGRESS: at 96.96% examples, 73804 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:42:18,470 : INFO : EPOCH 1 - PROGRESS: at 97.32% examples, 73730 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:19,522 : INFO : EPOCH 1 - PROGRESS: at 97.76% examples, 73720 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:20,523 : INFO : EPOCH 1 - PROGRESS: at 98.14% examples, 73728 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:21,540 : INFO : EPOCH 1 - PROGRESS: at 98.56% examples, 73729 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:22,654 : INFO : EPOCH 1 - PROGRESS: at 99.02% examples, 73729 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:23,079 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-08-20 16:42:23,083 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-08-20 16:42:23,090 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-08-20 16:42:23,092 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-08-20 16:42:23,093 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-08-20 16:42:23,106 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-08-20 16:42:23,110 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-08-20 16:42:23,112 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-08-20 16:42:23,112 : INFO : EPOCH - 1 : training on 26838128 raw words (18804456 effective words) took 253.0s, 74317 effective words/s
# 2019-08-20 16:42:24,842 : INFO : EPOCH 2 - PROGRESS: at 0.04% examples, 3946 words/s, in_qsize 10, out_qsize 0
# 2019-08-20 16:42:25,929 : INFO : EPOCH 2 - PROGRESS: at 0.31% examples, 19329 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:26,965 : INFO : EPOCH 2 - PROGRESS: at 0.72% examples, 33677 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:28,235 : INFO : EPOCH 2 - PROGRESS: at 1.24% examples, 44065 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:29,241 : INFO : EPOCH 2 - PROGRESS: at 1.64% examples, 49148 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:30,332 : INFO : EPOCH 2 - PROGRESS: at 2.09% examples, 53159 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:31,342 : INFO : EPOCH 2 - PROGRESS: at 2.50% examples, 55826 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:32,376 : INFO : EPOCH 2 - PROGRESS: at 2.91% examples, 57805 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:33,426 : INFO : EPOCH 2 - PROGRESS: at 3.31% examples, 59271 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:34,548 : INFO : EPOCH 2 - PROGRESS: at 3.75% examples, 60702 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:35,652 : INFO : EPOCH 2 - PROGRESS: at 4.18% examples, 61910 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:36,693 : INFO : EPOCH 2 - PROGRESS: at 4.60% examples, 62758 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:37,723 : INFO : EPOCH 2 - PROGRESS: at 5.00% examples, 63471 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:38,783 : INFO : EPOCH 2 - PROGRESS: at 5.41% examples, 63984 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:39,847 : INFO : EPOCH 2 - PROGRESS: at 5.84% examples, 64872 words/s, in_qsize 13, out_qsize 1
# 2019-08-20 16:42:40,985 : INFO : EPOCH 2 - PROGRESS: at 6.23% examples, 64992 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:42:42,007 : INFO : EPOCH 2 - PROGRESS: at 6.58% examples, 65116 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:43,211 : INFO : EPOCH 2 - PROGRESS: at 7.04% examples, 65624 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:44,250 : INFO : EPOCH 2 - PROGRESS: at 7.44% examples, 65992 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:45,281 : INFO : EPOCH 2 - PROGRESS: at 7.86% examples, 66323 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:46,432 : INFO : EPOCH 2 - PROGRESS: at 8.30% examples, 66615 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:47,450 : INFO : EPOCH 2 - PROGRESS: at 8.67% examples, 66923 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:48,567 : INFO : EPOCH 2 - PROGRESS: at 9.13% examples, 67225 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:49,597 : INFO : EPOCH 2 - PROGRESS: at 9.53% examples, 67462 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:50,601 : INFO : EPOCH 2 - PROGRESS: at 9.92% examples, 67747 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:51,639 : INFO : EPOCH 2 - PROGRESS: at 10.30% examples, 67935 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:52,741 : INFO : EPOCH 2 - PROGRESS: at 10.72% examples, 68152 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:53,864 : INFO : EPOCH 2 - PROGRESS: at 11.16% examples, 68313 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:54,879 : INFO : EPOCH 2 - PROGRESS: at 11.59% examples, 68510 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:55,887 : INFO : EPOCH 2 - PROGRESS: at 12.02% examples, 68697 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:42:56,947 : INFO : EPOCH 2 - PROGRESS: at 12.42% examples, 68798 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:58,043 : INFO : EPOCH 2 - PROGRESS: at 12.83% examples, 68992 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:42:59,048 : INFO : EPOCH 2 - PROGRESS: at 13.22% examples, 69154 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:00,153 : INFO : EPOCH 2 - PROGRESS: at 13.66% examples, 69333 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:01,264 : INFO : EPOCH 2 - PROGRESS: at 14.11% examples, 69478 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:02,344 : INFO : EPOCH 2 - PROGRESS: at 14.57% examples, 69677 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:03,371 : INFO : EPOCH 2 - PROGRESS: at 14.96% examples, 69766 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:04,450 : INFO : EPOCH 2 - PROGRESS: at 15.38% examples, 69930 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:05,493 : INFO : EPOCH 2 - PROGRESS: at 15.78% examples, 69984 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:06,499 : INFO : EPOCH 2 - PROGRESS: at 16.17% examples, 70103 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:07,644 : INFO : EPOCH 2 - PROGRESS: at 16.66% examples, 70308 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:08,668 : INFO : EPOCH 2 - PROGRESS: at 17.05% examples, 70381 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:09,696 : INFO : EPOCH 2 - PROGRESS: at 17.51% examples, 70598 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:10,759 : INFO : EPOCH 2 - PROGRESS: at 17.88% examples, 70586 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:11,787 : INFO : EPOCH 2 - PROGRESS: at 18.25% examples, 70629 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:12,811 : INFO : EPOCH 2 - PROGRESS: at 18.63% examples, 70701 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:13,821 : INFO : EPOCH 2 - PROGRESS: at 19.04% examples, 70793 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:14,844 : INFO : EPOCH 2 - PROGRESS: at 19.43% examples, 70853 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:15,858 : INFO : EPOCH 2 - PROGRESS: at 19.83% examples, 70915 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:16,900 : INFO : EPOCH 2 - PROGRESS: at 20.24% examples, 70952 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:17,901 : INFO : EPOCH 2 - PROGRESS: at 20.65% examples, 71033 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:18,911 : INFO : EPOCH 2 - PROGRESS: at 21.05% examples, 71096 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:20,017 : INFO : EPOCH 2 - PROGRESS: at 21.47% examples, 71154 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:21,059 : INFO : EPOCH 2 - PROGRESS: at 21.88% examples, 71177 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:22,073 : INFO : EPOCH 2 - PROGRESS: at 22.29% examples, 71238 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:23,205 : INFO : EPOCH 2 - PROGRESS: at 22.71% examples, 71251 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:24,243 : INFO : EPOCH 2 - PROGRESS: at 23.14% examples, 71294 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:25,342 : INFO : EPOCH 2 - PROGRESS: at 23.57% examples, 71358 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:26,370 : INFO : EPOCH 2 - PROGRESS: at 23.96% examples, 71392 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:27,402 : INFO : EPOCH 2 - PROGRESS: at 24.39% examples, 71511 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:28,452 : INFO : EPOCH 2 - PROGRESS: at 24.79% examples, 71525 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:29,464 : INFO : EPOCH 2 - PROGRESS: at 25.25% examples, 71679 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:43:30,484 : INFO : EPOCH 2 - PROGRESS: at 25.62% examples, 71625 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:31,493 : INFO : EPOCH 2 - PROGRESS: at 26.04% examples, 71677 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:32,513 : INFO : EPOCH 2 - PROGRESS: at 26.44% examples, 71694 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:33,572 : INFO : EPOCH 2 - PROGRESS: at 26.84% examples, 71693 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:34,691 : INFO : EPOCH 2 - PROGRESS: at 27.27% examples, 71719 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:35,735 : INFO : EPOCH 2 - PROGRESS: at 27.66% examples, 71729 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:36,748 : INFO : EPOCH 2 - PROGRESS: at 28.07% examples, 71768 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:37,784 : INFO : EPOCH 2 - PROGRESS: at 28.54% examples, 71879 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:38,849 : INFO : EPOCH 2 - PROGRESS: at 28.98% examples, 71963 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:40,068 : INFO : EPOCH 2 - PROGRESS: at 29.42% examples, 71883 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:41,087 : INFO : EPOCH 2 - PROGRESS: at 29.82% examples, 71912 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:42,111 : INFO : EPOCH 2 - PROGRESS: at 30.23% examples, 71935 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:43,190 : INFO : EPOCH 2 - PROGRESS: at 30.67% examples, 72001 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:44,202 : INFO : EPOCH 2 - PROGRESS: at 31.08% examples, 72038 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:45,316 : INFO : EPOCH 2 - PROGRESS: at 31.52% examples, 72063 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:46,384 : INFO : EPOCH 2 - PROGRESS: at 31.94% examples, 72131 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:47,418 : INFO : EPOCH 2 - PROGRESS: at 32.34% examples, 72146 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:48,443 : INFO : EPOCH 2 - PROGRESS: at 32.73% examples, 72156 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:49,484 : INFO : EPOCH 2 - PROGRESS: at 33.17% examples, 72244 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:50,534 : INFO : EPOCH 2 - PROGRESS: at 33.55% examples, 72233 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:51,611 : INFO : EPOCH 2 - PROGRESS: at 33.97% examples, 72288 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:52,636 : INFO : EPOCH 2 - PROGRESS: at 34.36% examples, 72303 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:53,636 : INFO : EPOCH 2 - PROGRESS: at 34.77% examples, 72345 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:54,781 : INFO : EPOCH 2 - PROGRESS: at 35.18% examples, 72342 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:55,825 : INFO : EPOCH 2 - PROGRESS: at 35.57% examples, 72346 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:43:56,857 : INFO : EPOCH 2 - PROGRESS: at 35.99% examples, 72426 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:43:57,904 : INFO : EPOCH 2 - PROGRESS: at 36.37% examples, 72425 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:43:58,933 : INFO : EPOCH 2 - PROGRESS: at 36.76% examples, 72446 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:00,018 : INFO : EPOCH 2 - PROGRESS: at 37.17% examples, 72483 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:01,026 : INFO : EPOCH 2 - PROGRESS: at 37.57% examples, 72513 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:02,094 : INFO : EPOCH 2 - PROGRESS: at 38.02% examples, 72565 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:03,175 : INFO : EPOCH 2 - PROGRESS: at 38.40% examples, 72534 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:44:04,204 : INFO : EPOCH 2 - PROGRESS: at 38.84% examples, 72606 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:44:05,218 : INFO : EPOCH 2 - PROGRESS: at 39.20% examples, 72554 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:06,352 : INFO : EPOCH 2 - PROGRESS: at 39.63% examples, 72551 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:44:07,355 : INFO : EPOCH 2 - PROGRESS: at 39.99% examples, 72502 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:08,366 : INFO : EPOCH 2 - PROGRESS: at 40.43% examples, 72592 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:44:09,422 : INFO : EPOCH 2 - PROGRESS: at 40.81% examples, 72520 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:10,489 : INFO : EPOCH 2 - PROGRESS: at 41.22% examples, 72507 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:11,639 : INFO : EPOCH 2 - PROGRESS: at 41.63% examples, 72494 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:12,648 : INFO : EPOCH 2 - PROGRESS: at 42.02% examples, 72519 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:44:13,664 : INFO : EPOCH 2 - PROGRESS: at 42.36% examples, 72468 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:14,738 : INFO : EPOCH 2 - PROGRESS: at 42.76% examples, 72452 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:15,929 : INFO : EPOCH 2 - PROGRESS: at 43.24% examples, 72488 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:16,933 : INFO : EPOCH 2 - PROGRESS: at 43.65% examples, 72516 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:17,989 : INFO : EPOCH 2 - PROGRESS: at 44.04% examples, 72508 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:19,094 : INFO : EPOCH 2 - PROGRESS: at 44.43% examples, 72458 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:20,113 : INFO : EPOCH 2 - PROGRESS: at 44.84% examples, 72474 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:21,141 : INFO : EPOCH 2 - PROGRESS: at 45.22% examples, 72485 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:22,182 : INFO : EPOCH 2 - PROGRESS: at 45.59% examples, 72483 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:23,377 : INFO : EPOCH 2 - PROGRESS: at 46.05% examples, 72503 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:24,413 : INFO : EPOCH 2 - PROGRESS: at 46.46% examples, 72514 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:25,421 : INFO : EPOCH 2 - PROGRESS: at 46.90% examples, 72586 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:26,423 : INFO : EPOCH 2 - PROGRESS: at 47.27% examples, 72552 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:27,568 : INFO : EPOCH 2 - PROGRESS: at 47.73% examples, 72598 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:28,593 : INFO : EPOCH 2 - PROGRESS: at 48.14% examples, 72607 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:29,962 : INFO : EPOCH 2 - PROGRESS: at 48.66% examples, 72631 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:30,972 : INFO : EPOCH 2 - PROGRESS: at 49.09% examples, 72695 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:32,044 : INFO : EPOCH 2 - PROGRESS: at 49.50% examples, 72678 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:33,103 : INFO : EPOCH 2 - PROGRESS: at 49.89% examples, 72665 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:34,112 : INFO : EPOCH 2 - PROGRESS: at 50.28% examples, 72680 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:35,148 : INFO : EPOCH 2 - PROGRESS: at 50.68% examples, 72684 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:36,182 : INFO : EPOCH 2 - PROGRESS: at 51.07% examples, 72687 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:37,215 : INFO : EPOCH 2 - PROGRESS: at 51.49% examples, 72691 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:38,347 : INFO : EPOCH 2 - PROGRESS: at 51.93% examples, 72692 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:39,365 : INFO : EPOCH 2 - PROGRESS: at 52.35% examples, 72707 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:40,417 : INFO : EPOCH 2 - PROGRESS: at 52.79% examples, 72747 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:41,463 : INFO : EPOCH 2 - PROGRESS: at 53.17% examples, 72697 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:42,594 : INFO : EPOCH 2 - PROGRESS: at 53.62% examples, 72704 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:43,610 : INFO : EPOCH 2 - PROGRESS: at 54.04% examples, 72722 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:44,624 : INFO : EPOCH 2 - PROGRESS: at 54.47% examples, 72735 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:45,630 : INFO : EPOCH 2 - PROGRESS: at 54.86% examples, 72750 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:46,694 : INFO : EPOCH 2 - PROGRESS: at 55.26% examples, 72736 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:47,810 : INFO : EPOCH 2 - PROGRESS: at 55.69% examples, 72740 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:48,839 : INFO : EPOCH 2 - PROGRESS: at 56.10% examples, 72745 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:49,854 : INFO : EPOCH 2 - PROGRESS: at 56.49% examples, 72754 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:50,872 : INFO : EPOCH 2 - PROGRESS: at 56.90% examples, 72765 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:51,874 : INFO : EPOCH 2 - PROGRESS: at 57.30% examples, 72785 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:52,888 : INFO : EPOCH 2 - PROGRESS: at 57.70% examples, 72799 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:53,897 : INFO : EPOCH 2 - PROGRESS: at 58.08% examples, 72813 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:44:54,935 : INFO : EPOCH 2 - PROGRESS: at 58.47% examples, 72816 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:55,941 : INFO : EPOCH 2 - PROGRESS: at 58.87% examples, 72834 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:56,954 : INFO : EPOCH 2 - PROGRESS: at 59.28% examples, 72847 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:57,998 : INFO : EPOCH 2 - PROGRESS: at 59.73% examples, 72877 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:44:59,023 : INFO : EPOCH 2 - PROGRESS: at 60.11% examples, 72840 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:00,084 : INFO : EPOCH 2 - PROGRESS: at 60.49% examples, 72832 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:01,085 : INFO : EPOCH 2 - PROGRESS: at 60.91% examples, 72851 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:02,265 : INFO : EPOCH 2 - PROGRESS: at 61.34% examples, 72829 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:03,309 : INFO : EPOCH 2 - PROGRESS: at 61.74% examples, 72826 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:04,390 : INFO : EPOCH 2 - PROGRESS: at 62.18% examples, 72849 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:05,423 : INFO : EPOCH 2 - PROGRESS: at 62.65% examples, 72940 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:45:06,453 : INFO : EPOCH 2 - PROGRESS: at 63.02% examples, 72899 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:07,473 : INFO : EPOCH 2 - PROGRESS: at 63.41% examples, 72905 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:08,551 : INFO : EPOCH 2 - PROGRESS: at 63.84% examples, 72922 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:09,649 : INFO : EPOCH 2 - PROGRESS: at 64.27% examples, 72929 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:10,658 : INFO : EPOCH 2 - PROGRESS: at 64.72% examples, 72983 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:11,681 : INFO : EPOCH 2 - PROGRESS: at 65.09% examples, 72988 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:12,876 : INFO : EPOCH 2 - PROGRESS: at 65.55% examples, 72960 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:13,970 : INFO : EPOCH 2 - PROGRESS: at 65.96% examples, 72970 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:15,051 : INFO : EPOCH 2 - PROGRESS: at 66.40% examples, 72988 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:16,136 : INFO : EPOCH 2 - PROGRESS: at 66.84% examples, 73005 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:17,209 : INFO : EPOCH 2 - PROGRESS: at 67.29% examples, 73029 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:18,212 : INFO : EPOCH 2 - PROGRESS: at 67.72% examples, 73078 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:19,253 : INFO : EPOCH 2 - PROGRESS: at 68.11% examples, 73072 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:20,347 : INFO : EPOCH 2 - PROGRESS: at 68.55% examples, 73090 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:21,359 : INFO : EPOCH 2 - PROGRESS: at 68.90% examples, 73093 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:22,439 : INFO : EPOCH 2 - PROGRESS: at 69.34% examples, 73110 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:23,451 : INFO : EPOCH 2 - PROGRESS: at 69.79% examples, 73154 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:24,511 : INFO : EPOCH 2 - PROGRESS: at 70.16% examples, 73145 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:25,512 : INFO : EPOCH 2 - PROGRESS: at 70.58% examples, 73157 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:45:26,596 : INFO : EPOCH 2 - PROGRESS: at 70.99% examples, 73169 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:27,596 : INFO : EPOCH 2 - PROGRESS: at 71.39% examples, 73181 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:28,611 : INFO : EPOCH 2 - PROGRESS: at 71.79% examples, 73188 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:29,871 : INFO : EPOCH 2 - PROGRESS: at 72.30% examples, 73210 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:45:31,031 : INFO : EPOCH 2 - PROGRESS: at 72.76% examples, 73228 words/s, in_qsize 15, out_qsize 0
# ...
# 2019-08-20 16:48:31,867 : INFO : EPOCH 3 - PROGRESS: at 44.22% examples, 72941 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:32,959 : INFO : EPOCH 3 - PROGRESS: at 44.65% examples, 72963 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:34,058 : INFO : EPOCH 3 - PROGRESS: at 45.07% examples, 72983 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:35,180 : INFO : EPOCH 3 - PROGRESS: at 45.49% examples, 72983 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:36,193 : INFO : EPOCH 3 - PROGRESS: at 45.87% examples, 73002 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:37,338 : INFO : EPOCH 3 - PROGRESS: at 46.32% examples, 72991 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:38,363 : INFO : EPOCH 3 - PROGRESS: at 46.71% examples, 72996 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:39,364 : INFO : EPOCH 3 - PROGRESS: at 47.11% examples, 73014 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:40,462 : INFO : EPOCH 3 - PROGRESS: at 47.55% examples, 73029 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:41,476 : INFO : EPOCH 3 - PROGRESS: at 47.94% examples, 73043 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:42,592 : INFO : EPOCH 3 - PROGRESS: at 48.37% examples, 73042 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:43,718 : INFO : EPOCH 3 - PROGRESS: at 48.81% examples, 73043 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:44,719 : INFO : EPOCH 3 - PROGRESS: at 49.19% examples, 73054 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:45,762 : INFO : EPOCH 3 - PROGRESS: at 49.60% examples, 73053 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:46,791 : INFO : EPOCH 3 - PROGRESS: at 50.00% examples, 73052 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:47,818 : INFO : EPOCH 3 - PROGRESS: at 50.39% examples, 73055 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:48,882 : INFO : EPOCH 3 - PROGRESS: at 50.79% examples, 73040 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:50,003 : INFO : EPOCH 3 - PROGRESS: at 51.22% examples, 73048 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:51,069 : INFO : EPOCH 3 - PROGRESS: at 51.63% examples, 73028 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:52,104 : INFO : EPOCH 3 - PROGRESS: at 52.04% examples, 73027 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:48:53,135 : INFO : EPOCH 3 - PROGRESS: at 52.47% examples, 73033 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:54,173 : INFO : EPOCH 3 - PROGRESS: at 52.86% examples, 73027 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:55,227 : INFO : EPOCH 3 - PROGRESS: at 53.28% examples, 73022 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:48:56,365 : INFO : EPOCH 3 - PROGRESS: at 53.74% examples, 73020 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:57,398 : INFO : EPOCH 3 - PROGRESS: at 54.16% examples, 73028 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:58,503 : INFO : EPOCH 3 - PROGRESS: at 54.60% examples, 73039 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:48:59,552 : INFO : EPOCH 3 - PROGRESS: at 54.99% examples, 73027 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:00,578 : INFO : EPOCH 3 - PROGRESS: at 55.40% examples, 73026 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:01,625 : INFO : EPOCH 3 - PROGRESS: at 55.81% examples, 73021 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:02,669 : INFO : EPOCH 3 - PROGRESS: at 56.24% examples, 73059 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:03,676 : INFO : EPOCH 3 - PROGRESS: at 56.61% examples, 73026 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:04,810 : INFO : EPOCH 3 - PROGRESS: at 57.07% examples, 73074 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:05,832 : INFO : EPOCH 3 - PROGRESS: at 57.49% examples, 73077 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:06,878 : INFO : EPOCH 3 - PROGRESS: at 57.84% examples, 73027 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:07,886 : INFO : EPOCH 3 - PROGRESS: at 58.21% examples, 73045 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:08,933 : INFO : EPOCH 3 - PROGRESS: at 58.62% examples, 73040 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:09,960 : INFO : EPOCH 3 - PROGRESS: at 59.02% examples, 73046 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:10,993 : INFO : EPOCH 3 - PROGRESS: at 59.42% examples, 73047 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:12,059 : INFO : EPOCH 3 - PROGRESS: at 59.85% examples, 73026 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:13,079 : INFO : EPOCH 3 - PROGRESS: at 60.23% examples, 73034 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:14,106 : INFO : EPOCH 3 - PROGRESS: at 60.63% examples, 73041 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:15,227 : INFO : EPOCH 3 - PROGRESS: at 61.08% examples, 73044 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:16,259 : INFO : EPOCH 3 - PROGRESS: at 61.48% examples, 73048 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:17,262 : INFO : EPOCH 3 - PROGRESS: at 61.88% examples, 73060 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:18,295 : INFO : EPOCH 3 - PROGRESS: at 62.30% examples, 73064 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:19,315 : INFO : EPOCH 3 - PROGRESS: at 62.69% examples, 73074 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:20,409 : INFO : EPOCH 3 - PROGRESS: at 63.13% examples, 73088 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:21,415 : INFO : EPOCH 3 - PROGRESS: at 63.56% examples, 73141 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:22,445 : INFO : EPOCH 3 - PROGRESS: at 63.96% examples, 73134 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:23,461 : INFO : EPOCH 3 - PROGRESS: at 64.35% examples, 73140 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:24,557 : INFO : EPOCH 3 - PROGRESS: at 64.79% examples, 73154 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:25,655 : INFO : EPOCH 3 - PROGRESS: at 65.21% examples, 73166 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:26,834 : INFO : EPOCH 3 - PROGRESS: at 65.68% examples, 73184 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:27,881 : INFO : EPOCH 3 - PROGRESS: at 66.08% examples, 73175 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:28,928 : INFO : EPOCH 3 - PROGRESS: at 66.48% examples, 73167 words/s, in_qsize 14, out_qsize 1
# 2019-08-20 16:49:29,937 : INFO : EPOCH 3 - PROGRESS: at 66.89% examples, 73175 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:31,024 : INFO : EPOCH 3 - PROGRESS: at 67.32% examples, 73193 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:32,109 : INFO : EPOCH 3 - PROGRESS: at 67.76% examples, 73210 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:33,308 : INFO : EPOCH 3 - PROGRESS: at 68.22% examples, 73215 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:34,333 : INFO : EPOCH 3 - PROGRESS: at 68.62% examples, 73220 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:35,409 : INFO : EPOCH 3 - PROGRESS: at 69.01% examples, 73234 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:36,433 : INFO : EPOCH 3 - PROGRESS: at 69.45% examples, 73273 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:37,481 : INFO : EPOCH 3 - PROGRESS: at 69.89% examples, 73304 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:38,557 : INFO : EPOCH 3 - PROGRESS: at 70.27% examples, 73284 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:39,569 : INFO : EPOCH 3 - PROGRESS: at 70.68% examples, 73293 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:40,658 : INFO : EPOCH 3 - PROGRESS: at 71.09% examples, 73302 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:41,692 : INFO : EPOCH 3 - PROGRESS: at 71.49% examples, 73299 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:42,871 : INFO : EPOCH 3 - PROGRESS: at 72.00% examples, 73349 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:43,930 : INFO : EPOCH 3 - PROGRESS: at 72.39% examples, 73340 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:44,987 : INFO : EPOCH 3 - PROGRESS: at 72.83% examples, 73360 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:46,019 : INFO : EPOCH 3 - PROGRESS: at 73.22% examples, 73359 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:47,200 : INFO : EPOCH 3 - PROGRESS: at 73.65% examples, 73365 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:48,203 : INFO : EPOCH 3 - PROGRESS: at 74.06% examples, 73374 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:49,225 : INFO : EPOCH 3 - PROGRESS: at 74.45% examples, 73371 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:50,254 : INFO : EPOCH 3 - PROGRESS: at 74.86% examples, 73376 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:51,256 : INFO : EPOCH 3 - PROGRESS: at 75.26% examples, 73386 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:52,412 : INFO : EPOCH 3 - PROGRESS: at 75.69% examples, 73372 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:53,477 : INFO : EPOCH 3 - PROGRESS: at 76.12% examples, 73394 words/s, in_qsize 14, out_qsize 0
# 2019-08-20 16:49:54,492 : INFO : EPOCH 3 - PROGRESS: at 76.48% examples, 73367 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:55,512 : INFO : EPOCH 3 - PROGRESS: at 76.91% examples, 73374 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:56,611 : INFO : EPOCH 3 - PROGRESS: at 77.35% examples, 73382 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:57,670 : INFO : EPOCH 3 - PROGRESS: at 77.76% examples, 73371 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:49:58,706 : INFO : EPOCH 3 - PROGRESS: at 78.15% examples, 73369 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:49:59,720 : INFO : EPOCH 3 - PROGRESS: at 78.54% examples, 73373 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:00,766 : INFO : EPOCH 3 - PROGRESS: at 78.96% examples, 73370 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:01,798 : INFO : EPOCH 3 - PROGRESS: at 79.39% examples, 73369 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:02,815 : INFO : EPOCH 3 - PROGRESS: at 79.81% examples, 73373 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:03,894 : INFO : EPOCH 3 - PROGRESS: at 80.24% examples, 73386 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:04,970 : INFO : EPOCH 3 - PROGRESS: at 80.66% examples, 73371 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:05,999 : INFO : EPOCH 3 - PROGRESS: at 81.09% examples, 73376 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:07,039 : INFO : EPOCH 3 - PROGRESS: at 81.51% examples, 73373 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:08,077 : INFO : EPOCH 3 - PROGRESS: at 81.95% examples, 73369 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:09,103 : INFO : EPOCH 3 - PROGRESS: at 82.34% examples, 73371 words/s, in_qsize 15, out_qsize 1
# 2019-08-20 16:50:10,123 : INFO : EPOCH 3 - PROGRESS: at 82.73% examples, 73377 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:11,253 : INFO : EPOCH 3 - PROGRESS: at 83.18% examples, 73372 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:12,294 : INFO : EPOCH 3 - PROGRESS: at 83.61% examples, 73367 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:13,335 : INFO : EPOCH 3 - PROGRESS: at 84.04% examples, 73363 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:14,419 : INFO : EPOCH 3 - PROGRESS: at 84.47% examples, 73373 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:15,469 : INFO : EPOCH 3 - PROGRESS: at 84.88% examples, 73369 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:16,493 : INFO : EPOCH 3 - PROGRESS: at 85.27% examples, 73369 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:17,549 : INFO : EPOCH 3 - PROGRESS: at 85.69% examples, 73363 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:18,718 : INFO : EPOCH 3 - PROGRESS: at 86.19% examples, 73380 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:19,732 : INFO : EPOCH 3 - PROGRESS: at 86.55% examples, 73355 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:20,750 : INFO : EPOCH 3 - PROGRESS: at 86.95% examples, 73363 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:21,933 : INFO : EPOCH 3 - PROGRESS: at 87.44% examples, 73379 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:22,945 : INFO : EPOCH 3 - PROGRESS: at 87.84% examples, 73385 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:23,963 : INFO : EPOCH 3 - PROGRESS: at 88.24% examples, 73386 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:24,968 : INFO : EPOCH 3 - PROGRESS: at 88.62% examples, 73392 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:25,993 : INFO : EPOCH 3 - PROGRESS: at 89.03% examples, 73395 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:26,998 : INFO : EPOCH 3 - PROGRESS: at 89.46% examples, 73403 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:28,067 : INFO : EPOCH 3 - PROGRESS: at 89.90% examples, 73419 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:29,084 : INFO : EPOCH 3 - PROGRESS: at 90.35% examples, 73452 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:30,085 : INFO : EPOCH 3 - PROGRESS: at 90.75% examples, 73458 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:31,105 : INFO : EPOCH 3 - PROGRESS: at 91.11% examples, 73428 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:32,125 : INFO : EPOCH 3 - PROGRESS: at 91.52% examples, 73428 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:33,190 : INFO : EPOCH 3 - PROGRESS: at 91.94% examples, 73415 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:34,228 : INFO : EPOCH 3 - PROGRESS: at 92.35% examples, 73411 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:35,346 : INFO : EPOCH 3 - PROGRESS: at 92.81% examples, 73413 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:36,373 : INFO : EPOCH 3 - PROGRESS: at 93.25% examples, 73439 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:37,429 : INFO : EPOCH 3 - PROGRESS: at 93.65% examples, 73431 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:38,507 : INFO : EPOCH 3 - PROGRESS: at 94.10% examples, 73443 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:39,648 : INFO : EPOCH 3 - PROGRESS: at 94.55% examples, 73440 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:40,723 : INFO : EPOCH 3 - PROGRESS: at 95.01% examples, 73453 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:41,813 : INFO : EPOCH 3 - PROGRESS: at 95.46% examples, 73461 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:42,815 : INFO : EPOCH 3 - PROGRESS: at 95.88% examples, 73471 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:43,892 : INFO : EPOCH 3 - PROGRESS: at 96.32% examples, 73480 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:44,923 : INFO : EPOCH 3 - PROGRESS: at 96.75% examples, 73477 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:46,008 : INFO : EPOCH 3 - PROGRESS: at 97.18% examples, 73485 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:47,029 : INFO : EPOCH 3 - PROGRESS: at 97.61% examples, 73486 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:48,085 : INFO : EPOCH 3 - PROGRESS: at 98.00% examples, 73476 words/s, in_qsize 16, out_qsize 0
# 2019-08-20 16:50:49,167 : INFO : EPOCH 3 - PROGRESS: at 98.44% examples, 73487 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:50,184 : INFO : EPOCH 3 - PROGRESS: at 98.88% examples, 73491 words/s, in_qsize 15, out_qsize 0
# 2019-08-20 16:50:50,961 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-08-20 16:50:50,964 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-08-20 16:50:50,974 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-08-20 16:50:50,977 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-08-20 16:50:50,978 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-08-20 16:50:50,982 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-08-20 16:50:50,988 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-08-20 16:50:50,989 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-08-20 16:50:50,990 : INFO : EPOCH - 3 : training on 26838128 raw words (18801304 effective words) took 253.8s, 74085 effective words/s
# 2019-08-20 16:50:50,990 : INFO : training on a 80514384 raw words (56405355 effective words) took 760.9s, 74129 effective words/s
# CPU times: user 15min 20s, sys: 21.8 s, total: 15min 42s
# Wall time: 12min 40s

# %% [markdown]
# Now lets look and see if we can understand some similarities in between reviews

# %%
with open("data/imdb_movie_reviews/train/pos/9901_8.txt","r") as fileHandle:
    text = normalize_text(fileHandle.read())
    
print(text)
# Out:
# this movie looked like a classic in the cheesy 80s slasher genre ,  which is my favorite genre of them all ,  so when i saw it was free on demand ,  i had to watch it !  it stars caroline munro ,  from both dr .  phibes films  ( she was his wife that died !  )  ,  dracula a . d .  1972 ,  the golden voyage of sinbad ,  captain kronos - vampire hunter ,  the spy who loved me ,  maniac ,  and faceless .   brought to you by the people behind don't open til christmas and pieces ,  heres my thoughts on this .  .  .   it opens on april fools day ,  where a bunch of kids play an elaborate prank on the school nerd- promising him sex in the shower ,  and giving him public humiliation and a face in the toilet  ( all while hes naked !  )  .  the coach puts a stop to it ,  but both parties swear revenge .  but ,  the cool kids end up burning the nerd alive .   cut to the future ,  and its th high school reunion ,  or so they think  ( bwahahha ?  )  .  the only ones with invitations were the gang who burned the kid ,  and its april fools day  ( or really ,  the day before april fools ,  but the fun starts at midnight )  ,  yet they fail to see the coincidence and hang out in front of the school until nightfall .  then they finally break into the school and it starts storming .   inside they find food/drink and a little shrine for each of them ,  each of their lockers and belongings ,  along with marty's  ( the nerds )  locker and yearbook .  they also find the old black janitor/caretaker who spends his time saying  " oooh yesser !  yesser !  i don't want no trouble ,  sir !  "  and then is killed instantly .  pretty pointless character ,  but hes still my favorite .   the movie takes a page out of alien's book ,  in a deliciously gory way that you just have to see !  thats when everyone realizes that they're there to die ,  and they start freaking out ,  except for shirley ,  who decides it would be best to take a bath in the old school showers at a time like this .  of course ,  it pours out blood and acid and her face melts off  ( very cool ,  mind you )  the rest of the night goes as usual ,  sex ,  drugs ,  and marty killing everyone whilst wearing a jester mask .  .  whats their plan ?   " all we have to do is stay awake and wait till noon .  marty wont kill us during mid-day !  "  .  seriously ,  thats what he said .  apparently you can only kill at nighttime .  but will they survive through the night ?  who will live and who will die ?  and why are all the bodies disappearing ?  rent ,  buy ,  or steal this great movie to find out !  the movie is actually very good ,  filled with clichés  ( car wont start ,  dammit !  )  and just plain slasher fun .  not to mention they all have names like carol and nany and frank and joe and susan .  i recommend it to all of you !  and ,  not to mention ,  it has a spin off !  1989's cutting class is a spin-off from this slasher gem ,  and that movie starts the career of brad pitt and roddy mcdowell .   favorite scene :  2 people having sex ,  the guy wants to finish but the girl doesn't .   " talk dirty to me ,  frank !  !  "  she screams  " uh .  .  .  tits !  "   " dirtier !  "   " uh .  .  .  tits .  f*ck .  tits .  boobs .  f*ck .  "  .  it seems to work for her and at her climax ,  the killer electrocutes them both !

# %% [markdown]
# Here is the inferred document vector for this review:

# %%
tokens = word_tokenize(text.lower())
new_vector = model.infer_vector(tokens)
sims = model.docvecs.most_similar([new_vector],topn=10)
print(sims)
# Out:
# [('45121', 0.39297741651535034), ('85756', 0.3914135992527008), ('44679', 0.3826449513435364), ('49843', 0.37741243839263916), ('836', 0.3691520392894745), ('55268', 0.3668164014816284), ('52728', 0.36188164353370667), ('64782', 0.3617124855518341), ('89269', 0.3613439202308655), ('65784', 0.35799914598464966)]

# %%
most_similar_doc_path = document_iterator.doc_list[67349]
with open(most_similar_doc_path, 'r') as file:
    text = normalize_text(file.read())
    print(text)
# Out:
# i have just recently been through a stage where i wanted to see why it is that horror films of the 90's can't hold a candle to 70's and 80's horror films .  i have been very public in this forum about the vileness of films like the haunting and urban legend and such .  i feel that they  ( and others like them )  don't know what true horror is .  and it bothered me to the point where it made me go to my local video store and rent some of the classic horror films .  i already own all the friday's so i rented the texas chainsaw massacre ,  the original nightmare on elm street ,  jaws ,  the exorcist ,  angel heart ,  the exorcist and halloween .  now the other films are classics in their own right but it is here that i want to tell you about halloween .  because what halloween does is perhaps something no other film in the history of horror film can do ,  and that is it uses subtle techniques ,  techniques that don't rely on blood and gore ,  and it uses these to scare the living daylights out of you .  i was in a room by myself with the lights off and as silly as i knew it was ,  i wanted to look behind me to see if michael myers was there .  no movie that i have seen in the last ten years has done that to me .  no movie .   john carpenter took a low budget film and he scared a generation of movie goers .  he showed that you don't need budgets in the 8 or 9 figures to evoke fear on an audience .  because sometimes the best element of fear is not what actually happens ,  but what is about to happen .  what was that shadow ?  what was that noise upstairs ?  he knows that these are the ways to scare someone and he uses every element of textbook horror that i think you can use .  i even think he made up some of his own ideas and these should be ideas that people use today .  but they don't .  no one uses lighting and detail to provoke scares ,  they use special effects and rivers of blood .  and it is just not the same .  you can't be scared by a giant special effect that makes loud noises and jumps out of a wall .  it's the moments when the killer is lurking ,  somewhere ,  you just don't know where ,  that scare you .  and halloween succeeds like no other film in this endeavor .   in 1963 a young micael myers kills his sister with a large butcher knife and then spends the next 15 years of his life ,  silently locked up in an institute .  as loomis  (  his doctor )  says to sheriff brackett ,   "  i spent eight years trying to reach him and then another seven making sure that he never gets out ,  because what i saw behind those eyes was pure e-vil .   "  that sets up the manic and relentless idea of a killer that will stop at nothing to get what he wants .  and all he wants here is to kill laurie .  no one know why he wants to kill her ,  but he does .  (  halloween ii continues the story quite well  )   what carpenter has done here is taken a haunting score ,  mendacious lighting techniques and wrote and directed a tightly paced masterpiece of horror .  there is one scene that has to be described .  and that is the scene where annie is on her way to pick up paul .  she goes to the car and tries to open it .  only then does she realize that she has left her keys in the house .  she gets them ,  comes back out and inadvertently opens the car door without using the keys .  the audience picks up on this but she doesn't .  she is too busy thinking about paul .  when she sits down ,  she notices that the windows are fogged up .  she is puzzled and starts to wipe away the mist ,  and then myers strikes ,  from the back seat .  this is such a great scene because it pays attention to detail .  we know what is happening and annie doesn't .  but it's astute observations that carpenter made that scared the hell out of movie goers in 1978 and beyond .    halloween uses blurry images of a killer standing in the background ,  it has shadows ominously gliding across a wall ,  dark rooms ,  creepy and haunting music ,  a sinister story told haunti ...
